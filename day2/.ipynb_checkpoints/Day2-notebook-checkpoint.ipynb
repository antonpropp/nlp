# %%
import pandas as pd
import os

# %%
data = pd.read_csv('/Users/podsechka/nlp-roadmap/day2/train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
data.describe(include="number")
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.rename(columns = {'PassengerId':'Passenger_Id', 'Pclass':'P_class', 'SibSp':'Sib_Sp'}, inplace = True)

# %%
data.columns
# Out:
# Index(['Passenger_Id', 'Survived', 'P_class', 'Name', 'Sex', 'Age', 'Sib_Sp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data_cols = ['passenger_id', 'survived', 'p_class', 'name', 'sex', 'age', 'sib_sp',
       'parch', 'ticket', 'fare', 'cabin', 'embarked']

# %%
data.columns = data_cols

# %%
data.columns
# Out:
# Index(['passenger_id', 'survived', 'p_class', 'name', 'sex', 'age', 'sib_sp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
data = pd.read_csv('/Users/podsechka/nlp-roadmap/day2/train.csv', names = data_cols, header=0)
data.head(3)
# Out:
#    passenger_id  survived  p_class  \
# 0             1         0        3
# 1             2         1        1
# 2             3         1        3
#
#                                                 name     sex   age  sib_sp  \
# 0                            Braund, Mr. Owen Harris    male  22.0       1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                             Heikkinen, Miss. Laina  female  26.0       0
#
#    parch            ticket     fare cabin embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
data.columns
# Out:
# Index(['passenger_id', 'survived', 'p_class', 'name', 'sex', 'age', 'sib_sp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
data.columns  = data.columns.str.replace('????', '_')

# %%
data.columns
# Out:
# Index(['passenger_id', 'survived', 'p_class', 'name', 'sex', 'age', 'sib_sp',
#        'parch', 'ticket', 'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
data
# Out:
#      passenger_id  survived  p_class  \
# 0               1         0        3
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 4               5         0        3
# ..            ...       ...      ...
# 886           887         0        2
# 887           888         1        1
# 888           889         0        3
# 889           890         1        1
# 890           891         0        3
#
#                                                   name     sex   age  sib_sp  \
# 0                              Braund, Mr. Owen Harris    male  22.0       1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 4                             Allen, Mr. William Henry    male  35.0       0
# ...

# %%
os.makedirs('~/nlp-roadmap/day2', exist_ok=True)

# %%
data.to_pickle('~/nlp-roadmap/day2/titanic_clean.pkl')

# %%
mask = (data['sex'] == 'female') | (data['age'] < 14)

# %%
data.loc[mask]
# Out:
#      passenger_id  survived  p_class  \
# 1               2         1        1
# 2               3         1        3
# 3               4         1        1
# 7               8         0        3
# 8               9         1        3
# ..            ...       ...      ...
# 880           881         1        2
# 882           883         0        3
# 885           886         0        3
# 887           888         1        1
# 888           889         0        3
#
#                                                   name     sex   age  sib_sp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0       1
# 2                               Heikkinen, Miss. Laina  female  26.0       0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0       1
# 7                       Palsson, Master. Gosta Leonard    male   2.0       3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0       0
# ...

# %%
data.groupby('sex')['survived'].mean()
# Out:
# sex
# female    0.742038
# male      0.188908
# Name: survived, dtype: float64

# %%
mean_ser_age = data.loc[data['survived'] == 0, 'age'].mean()

# %%
mean_ser_age
# Out:
# np.float64(30.62617924528302)

# %%
data['survived'] == 0
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 886     True
# 887    False
# 888     True
# 889    False
# 890     True
# Name: survived, Length: 891, dtype: bool
